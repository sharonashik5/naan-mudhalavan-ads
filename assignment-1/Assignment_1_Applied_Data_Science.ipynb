# %% [markdown]
# **Assignment 1 - Applied Data Science**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Load the Dataset

# %%
df = pd.read_csv('House Price India.csv')

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# 2. Perform the below visualizations:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df.describe())
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# a. Univariate Analysis

# %%
# Histograms
plt.hist(df['Price'], bins=20)
plt.title('Distribution of Prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
# Boxplots
sns.boxplot(df['living area'])
plt.title('Boxplot of Living Area')
plt.xlabel('living area')
plt.show()

# %%
# barplots
sns.countplot(df['waterfront present'])
plt.title('Waterfront Present')
plt.xlabel('waterfront present')
plt.ylabel('Count')
plt.show()

# %%
# Scatterplots
plt.scatter(df['living area'], df['Price'])
plt.title('Living Area vs. Price')
plt.xlabel('living area')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# b. Bivariate Analysis

# %%
# Scatter plot of living area and price
sns.scatterplot(data=df, x='living area', y='Price', hue='number of bedrooms')
plt.show()

# # Heat map of correlation matrix
# corr = data.corr()
# sns.heatmap(corr, cmap='coolwarm', annot=True)
# plt.show()

# %%
# Pair plot of all variables
sns.pairplot(data=df, vars=['living area', 'lot area', 'Number of schools nearby', 'Distance from the airport'], hue='waterfront present')
plt.show()

# %% [markdown]
# c. Multi Variate Analysis

# %%
# Visualize the correlation matrix using a heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ii. Descriptive Statistics

# %%
# Descriptive statistics of numerical variables
print(df.describe())
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# iii. Handle missing values

# %%
# Drop rows with missing values
data = df.dropna()

# %%
# Impute missing values with the mean
df['Built Year'].fillna(df['Built Year'].mean(), inplace=True)
df['Renovation Year'].fillna(df['Renovation Year'].median(), inplace=True)
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
# Impute missing values with the mode
df['waterfront present'].fillna(df['waterfront present'].mode()[0], inplace=True)
df['condition of the house'].fillna(df['condition of the house'].mode()[0], inplace=True)
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...
